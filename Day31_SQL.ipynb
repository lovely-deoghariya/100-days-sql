# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/100-days-sql/blob/main/Day31_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("/content/drive/MyDrive/SQL/company.db")

# %%
pd.read_sql("""
SELECT name
FROM sqlite_master
WHERE type='table';
""", conn)
# Out:
#           name
# 0  departments
# 1    employees
# 2     products
# 3    customers
# 4       orders

# %%
#Today's topic
Introduction to the COUNT() aggregate function

# %%
#count the total number of employees in the employees table
pd.read_sql("""
SELECT COUNT(*)
FROM employees;
""", conn)
# Out:
#    COUNT(*)
# 0        30

# %%
#count the total number of departments
pd.read_sql("""
SELECT COUNT(*)
FROM departments;
""", conn)
# Out:
#    COUNT(*)
# 0        10

# %%
#count the total number of products
pd.read_sql("""
SELECT COUNT(*)
FROM products;
""", conn)
# Out:
#    COUNT(*)
# 0        25

# %%
#count the total number of customers
pd.read_sql("""
SELECT COUNT(*)
FROM customers;
""", conn)
# Out:
#    COUNT(*)
# 0        40

# %%
#count the total number of order
pd.read_sql("""
SELECT COUNT(*)
FROM orders;
""", conn)
# Out:
#    COUNT(*)
# 0       100
